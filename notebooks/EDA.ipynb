# %%
import pandas as pd

# %%
price_df = pd.read_csv("../data/raw/pricePerProvince.csv", encoding='latin1')
price_df
# Out:
#                    province  price per ¢/kWh
# 0                   Alberta             25.8
# 1          British Columbia             11.4
# 2                  Manitoba             10.2
# 3             New Brunswick             13.9
# 4   Newfoundland & Labrador             14.8
# 5               Nova Scotia             18.3
# 6     Northwest Territories             41.0
# 7                   Nunavut             35.4
# 8                   Ontario             14.1
# 9      Prince Edward Island             18.4
# 10                   Quebec              7.8
# 11             Saskatchewan             19.9
# 12          Yukon Territory             18.7

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   province         13 non-null     object
#  1   price per ¢/kWh  13 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 340.0+ bytes

# %%
sunlight_df = pd.read_csv("../data/raw/municip_kWh.csv", encoding='latin1', skiprows=[0, 1, 2, 4], skipfooter=2)
sunlight_df = sunlight_df.rename(columns={'Mois': 'Month'})
sunlight_df['Province'] = sunlight_df['Province'].str.split('/').str[0]
sunlight_df['Month'] = sunlight_df['Month'].str.split('/').str[0]
sunlight_df.to_csv("../data/processed/processed_municip_kWh.csv")
sunlight_df
# Out:
# C:\Users\Marcony1\AppData\Local\Temp\ipykernel_2104\2479432145.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   sunlight_df = pd.read_csv("../data/raw/municip_kWh.csv", encoding='latin1', skiprows=[0, 1, 2, 4], skipfooter=2)
#               Province   Municipality      Month  \
# 0              Alberta  Acadia Valley    January
# 1              Alberta  Acadia Valley   February
# 2              Alberta  Acadia Valley      March
# 3              Alberta  Acadia Valley      April
# 4              Alberta  Acadia Valley        May
# ...                ...            ...        ...
# 45573  Yukon Territory     Whitehorse  September
# 45574  Yukon Territory     Whitehorse    October
# 45575  Yukon Territory     Whitehorse   November
# 45576  Yukon Territory     Whitehorse   December
# 45577  Yukon Territory     Whitehorse     Annual
#
# ...

# %%
sunlight_df[["Province", "Municipality"]].value_counts()
# Out:
# Province         Municipality
# Alberta          Acadia Valley                         13
# Ontario          Spencerville                          13
#                  Smithville                            13
#                  Smooth Rock Falls                     13
#                  Sombra                                13
#                                                        ..
# New Brunswick    Saint-Isidore                         13
#                  Saint-Jean-Baptiste-de-Restigouche    13
#                  Saint-Louis de Kent                   13
#                  Saint-LÃ©olin                         13
# Yukon Territory  Whitehorse                            13
# Name: count, Length: 3506, dtype: int64
